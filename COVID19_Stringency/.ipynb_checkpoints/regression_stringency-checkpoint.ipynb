# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.fixes import loguniform
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
import pandas as pd
df = pd.read_csv('states_covid_stringency.csv', parse_dates=True, dtype="category")

print(df.shape)
# Out:
# (18666, 31)

# %%
df.tail()
# Out:
#          CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 18661  United States         USA    Wyoming      US_WY   STATE_WIDE  20210302
# 18662  United States         USA    Wyoming      US_WY   STATE_WIDE  20210303
# 18663  United States         USA    Wyoming      US_WY   STATE_WIDE  20210304
# 18664  United States         USA    Wyoming      US_WY   STATE_WIDE  20210305
# 18665  United States         USA    Wyoming      US_WY   STATE_WIDE  20210306
#
#       C1_School closing C2_Workplace closing C3_Cancel public events  \
# 18661                 1                    1                       1
# 18662                 1                    1                       1
# 18663                 1                    1                       1
# 18664                 1                    1                       1
# 18665                 1                    1                       1
#
#       C4_Restrictions on gatherings  ... H8_Protection of elderly people  \
# ...

# %%
# df['deathIncrease'].describe()

# %%
# df['deathIncrease'] = pd.to_numeric(df['deathIncrease'], downcast="float")
# # df['deathsIncrease'] = df['deathsIncrease'].astype(str)
# # df['deathsIncrease'].dropna().quantile([0.0, .25, .75, 1])

# from sklearn.preprocessing import LabelEncoder

# label_encoder = LabelEncoder()

# # df['deathThreshold'] = label_encoder.fit_transform(pd.cut(df['deathIncrease'].astype(np.float64), [10, 50, 150, 1000], retbins=True)[0])
# df['deathThreshold'] = pd.cut(df['deathIncrease'].astype(np.int64), [-10, 20, 50, 1000], labels=[1,2,3])[0]

# %%
df.tail(500)
# df['deathIncrease'] = df['deathIncrease'].apply(pd.to_numeric)
# pd.qcut(df.deathIncrease, 3, labels=["low", "medium", "high"], retbins=True)
# Out:
#          CountryName CountryCode     RegionName RegionCode Jurisdiction  \
# 18166  United States         USA  West Virginia      US_WV   STATE_WIDE
# 18167  United States         USA  West Virginia      US_WV   STATE_WIDE
# 18168  United States         USA  West Virginia      US_WV   STATE_WIDE
# 18169  United States         USA  West Virginia      US_WV   STATE_WIDE
# 18170  United States         USA  West Virginia      US_WV   STATE_WIDE
# ...              ...         ...            ...        ...          ...
# 18661  United States         USA        Wyoming      US_WY   STATE_WIDE
# 18662  United States         USA        Wyoming      US_WY   STATE_WIDE
# 18663  United States         USA        Wyoming      US_WY   STATE_WIDE
# 18664  United States         USA        Wyoming      US_WY   STATE_WIDE
# 18665  United States         USA        Wyoming      US_WY   STATE_WIDE
#
#            Date C1_School closing C2_Workplace closing  \
# ...

# %%
# le = preprocessing.LabelEncoder()
# le.fit(df['policy_type_x'])
# list(le.classes_)
# df2 = le.transform(df['policy_type_x'])

# df['policy_type_x'] = df2

# %%
# print(df.iloc[:, df.columns != ['date_x', 'state_id', 'deathIncrease']])

# X = df.iloc[:, df.columns != ['deathsIncrease', 'CountryName'], axis=1]
X = df.drop(['CountryName', 'CountryCode', 'RegionName',
                              'RegionCode', 'Jurisdiction', 'Date','date', 'ConfirmedCases', 'ConfirmedDeaths'], axis=1)
y = df.iloc[:, df.columns == 'ConfirmedDeaths']

#X = df.drop(['CountryName', 'CountryCode', 'RegionName', 'RegionCode', 'Jurisdiction', 'Date', 'date', 'deathIncrease', 'C1_Notes', 
#             'C2_Notes', 'C3_Notes', 'C4_Notes', 'C5_Notes', 'C6_Notes', 'C7_Notes', 'C8_Notes', 'E1_Notes', 'E2_Notes', 
#             'E3_Notes', 'E4_Notes', 'H1_Notes', 'H8_Notes', 'H2_Notes', 'H3_Notes', 'H4_Notes', 'H5_Notes', 'H6_Notes',
#             'H7_Notes', 'M1_Notes'], axis=1)

# print(X.tail())
# print(y.tail())

print(X.dtypes)
print(y.dtypes)
# Out:
# C1_School closing                       category
# C2_Workplace closing                    category
# C3_Cancel public events                 category
# C4_Restrictions on gatherings           category
# C5_Close public transport               category
# C6_Stay at home requirements            category
# C7_Restrictions on internal movement    category
# C8_International travel controls        category
# E1_Income support                       category
# E2_Debt/contract relief                 category
# H1_Public information campaigns         category
# H2_Testing policy                       category
# H3_Contact tracing                      category
# H6_Facial Coverings                     category
# H7_Vaccination policy                   category
# H8_Protection of elderly people         category
# StringencyIndex                         category
# StringencyLegacyIndex                   category
# GovernmentResponseIndex                 category
# ...

# %%
X[['StringencyIndex', 'StringencyLegacyIndex', 'GovernmentResponseIndex', 
   'ContainmentHealthIndex', 'ContainmentHealthIndexForDisplay', 'deathIncrease']] = X[['StringencyIndex', 'StringencyLegacyIndex', 'GovernmentResponseIndex', 
   'ContainmentHealthIndex', 'ContainmentHealthIndexForDisplay', 'deathIncrease']].apply(pd.to_numeric)

# %%
# print(X.head())
# X = X.apply(pd.to_numeric)
y = y.astype(np.float64)
print(X.dtypes)
print(y.dtypes)
# Out:
# C1_School closing                       category
# C2_Workplace closing                    category
# C3_Cancel public events                 category
# C4_Restrictions on gatherings           category
# C5_Close public transport               category
# C6_Stay at home requirements            category
# C7_Restrictions on internal movement    category
# C8_International travel controls        category
# E1_Income support                       category
# E2_Debt/contract relief                 category
# H1_Public information campaigns         category
# H2_Testing policy                       category
# H3_Contact tracing                      category
# H6_Facial Coverings                     category
# H7_Vaccination policy                   category
# H8_Protection of elderly people         category
# StringencyIndex                          float64
# StringencyLegacyIndex                    float64
# GovernmentResponseIndex                  float64
# ...

# %%
from sklearn.feature_selection import SelectKBest, f_regression

fs = SelectKBest(score_func=f_regression, k=10)
# apply feature selection
X_selected = fs.fit(X, y)

#print(X_selected.shape)

df_scores = pd.DataFrame(X_selected.scores_)
df_columns = pd.DataFrame(X.columns)

print(df_scores)
print(df_columns)
# Out:
#               0
# 0     15.207254
# 1    237.898520
# 2     42.398845
# 3    551.137220
# 4     65.759984
# 5    265.242391
# 6    291.627577
# 7    453.137535
# 8    717.396829
# 9    646.005111
# 10   287.835525
# 11  1315.489611
# 12   334.643965
# 13  2391.157690
# 14  2197.027590
# 15   356.812772
# 16   133.659801
# 17   106.388973
# 18  1364.344631
# 19  1039.758688
# 20  1039.758688
# 21  6115.715681
#                                        0
# 0                      C1_School closing
# 1                   C2_Workplace closing
# 2                C3_Cancel public events
# 3          C4_Restrictions on gatherings
# 4              C5_Close public transport
# 5           C6_Stay at home requirements
# 6   C7_Restrictions on internal movement
# 7       C8_International travel controls
# 8                      E1_Income support
# 9                E2_Debt/contract relief
# 10       H1_Public information campaigns
# 11                     H2_Testing policy
# ...

# %%
# concatenate dataframes
feature_scores = pd.concat([df_columns, df_scores],axis=1)
feature_scores.columns = ['Feature_Name','Score']  # name output columns
print(feature_scores.nlargest(10,'Score'))  # print 20 best features
# export selected features to .csv
df_univ_feat = feature_scores.nlargest(10,'Score')
#df_univ_feat.to_csv('feature_selection_UNIVARIATE.csv', index=False)
# Out:
#                         Feature_Name        Score
# 21                     deathIncrease  6115.715681
# 13               H6_Facial Coverings  2391.157690
# 14             H7_Vaccination policy  2197.027590
# 18           GovernmentResponseIndex  1364.344631
# 11                 H2_Testing policy  1315.489611
# 19            ContainmentHealthIndex  1039.758688
# 20  ContainmentHealthIndexForDisplay  1039.758688
# 8                  E1_Income support   717.396829
# 9            E2_Debt/contract relief   646.005111
# 3      C4_Restrictions on gatherings   551.137220

# %%
# from sklearn.preprocessing import StandardScaler, MinMaxScaler
# # scaler = StandardScaler()
# # X_scaled = scaler.fit_transform(X)
# #y_scaled = scaler.fit_transform(y)

# norm = MinMaxScaler().fit_transform(df)

# %%
# X = df[['E2_Debt/contract relief', 'ConfirmedCases', 'ConfirmedDeaths', 'H7_Vaccination policy',
#         'EconomicSupportIndex', 'GovernmentResponseIndex']]
# X = df[['H7_Vaccination policy', 'GovernmentResponseIndex', 'H6_Facial Coverings', 'C6_Stay at home requirements',
#         'C4_Restrictions on gatherings', 'C2_Workplace closing', 'ContainmentHealthIndex']]
X = df[['deathIncrease', 'GovernmentResponseIndex', 'H6_Facial Coverings', 'H7_Vaccination policy']]
y = df.iloc[:, df.columns == 'ConfirmedDeaths']

print(X.head())
print(y.head())
# Out:
#   deathIncrease GovernmentResponseIndex H6_Facial Coverings  \
# 0             0                    8.33                   0
# 1             0                    8.33                   0
# 2             0                    8.33                   0
# 3             0                    8.33                   0
# 4             0                    8.33                   0
#
#   H7_Vaccination policy
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
#   ConfirmedDeaths
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
# from sklearn.preprocessing import StandardScaler, MinMaxScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
# y_scaled = scaler.fit_transform(y)

# # norm = MinMaxScaler().fit_transform(X)

# %%
param_dist = {'alpha': ['0.1', '0.25', '0.40', '0.5', '0.75', '1.0', '10', '50', '100', '500', '1000'],
              'fit_intercept': ['True', 'False'],
              'normalize': ['True', 'False'],
              'tol': loguniform(1e-4, 1e0),}

ridge_model = Ridge()

rrandom = RandomizedSearchCV(estimator=ridge_model, param_distributions=param_dist, cv=10, n_iter=100, random_state=42)
rrandom.fit(X, y)

print(rrandom.best_score_)
print(rrandom.best_estimator_.alpha)
print(rrandom.best_params_)
# Out:
# 0.00030540095107847167
# 0.40
# {'alpha': '0.40', 'fit_intercept': 'True', 'normalize': 'True', 'tol': 0.006870614282613298}

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
rfinal = Ridge(alpha= 0.40, fit_intercept=True, normalize=True, tol=0.006870614282613298)
rfinal.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.4, normalize=True, tol=0.006870614282613298)

# %%
pred = rfinal.predict(X_train)

# %%
print(np.sqrt(mean_squared_error(y_train, pred, squared=False)))
print(r2_score(y_train, pred))
# Out:
# 74.2029934058333
# 0.32566873773850924

# %%
fig, ax = plt.subplots()
ax.scatter(y_train, pred)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Truths')
ax.set_ylabel('Predicted Values')
ax.set_title('COVID-19 Deaths - Ridge Regression')
plt.show()
ax.figure.savefig("ridgeregression.jpg", transparent=True, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-474-11dd2bf01f9e> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.scatter(y_train, pred)
#       3 ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
#       4 ax.set_xlabel('Truths')
#       5 ax.set_ylabel('Predicted Values')
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# ...

# %%
from sklearn.linear_model import ElasticNet

# %%
param_dist = {"max_iter": [1, 5, 10, 100, 500],
                      "alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100],
                      "l1_ratio": np.arange(0.0, 1.0, 0.1)}

enet_model = ElasticNet()

rrandom = RandomizedSearchCV(estimator=enet_model, param_distributions=param_dist, cv=10, n_iter=100, random_state=42)
rrandom.fit(X, y)

print(rrandom.best_score_)
print(rrandom.best_estimator_.alpha)
print(rrandom.best_params_)
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 109230612.77087402, tolerance: 73775391.2561038
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160716670.53125, tolerance: 80242093.38776234
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 181993431.38287354, tolerance: 81814221.57015328
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
enetfinal = ElasticNet(max_iter=100, l1_ratio=0.1, alpha=1)
enetfinal.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=1, l1_ratio=0.1, max_iter=100)

# %%
pred = enetfinal.predict(X_train)

print(np.sqrt(mean_squared_error(y_train, pred, squared=False)))
print(r2_score(y_test, pred))
# Out:
# 74.09920368629726
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-499-fb93d4822bd9> in <module>
#       2
#       3 print(np.sqrt(mean_squared_error(y_train, pred, squared=False)))
# ----> 4 print(r2_score(y_test, pred))
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     586     -3.0
#     587     """
# --> 588     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     589         y_true, y_pred, multioutput)
#     590     check_consistent_length(y_true, y_pred, sample_weight)
#
# ...

# %%
en = ElasticNet(max_iter=100, l1_ratio=0.1, alpha=1)

cv = RepeatedKFold(n_splits = 5, n_repeats = 3, random_state=1)

scores = cross_val_score(en, X_train, y_train, cv=cv)

#scores

print('MAE: %.3f (%.3f)' % (mean(scores), std(scores)))

ypred = en.predict(X_test)

x_ax = range(len(X_test))
plt.scatter(x_ax, y_test, s=5, color="blue", label="original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()
# Out:
# MAE: 0.324 (0.034)
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-502-587577723807> in <module>
#       9 print('MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
#      10
# ---> 11 ypred = en.predict(X_test)
#      12
#      13 x_ax = range(len(X_test))
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py in _decision_function(self, X)
#     879             The predicted decision function
#     880         """
# --> 881         check_is_fitted(self)
#     882         if sparse.isspmatrix(X):
#     883             return safe_sparse_dot(X, self.coef_.T,
#
# ...

# %%
from sklearn.linear_model import ElasticNetCV

alphas = [0.0001, 0.001, 0.01, 0.1, 0.3, 0.5, 0.7, 1]

print(y_test)


elastic_cv=ElasticNetCV(alphas=alphas, cv=5)
model = elastic_cv.fit(X_train, y_train)
print(model.alpha_) 
print(model.intercept_) 

#We can predict xtest data and check the accuracy metrics.

ypred = model.predict(X_test)
score = model.score(X_test, y_test)
mse = mean_squared_error(y_test, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))

x_ax = range(len(y_test))
plt.scatter(x_ax, tuple(y_test), s=5, color="blue", label="original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()
# Out:
#       ConfirmedDeaths
# 5249             7014
# 17490            2941
# 13353             744
# 701              7566
# 12162             380
# ...               ...
# 11516           15925
# 6418             1060
# 9049             3597
# 14120            8101
# 763                10
#
# [5600 rows x 1 columns]
# 0.0001
# -2796.900421640765
# R2:0.381, MSE:30965248.23, RMSE:5564.64
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-530-11af59e1a28c> in <module>
#      20
#      21 x_ax = range(len(y_test))
# ---> 22 plt.scatter(x_ax, tuple(y_test), s=5, color="blue", label="original")
# ...

# %%
from sklearn.datasets import load_boston
from sklearn.linear_model import ElasticNet,ElasticNetCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.30)

alphas = [0.0001, 0.001, 0.01, 0.1, 0.3, 0.5, 0.7, 1]

for a in alphas:
    model = ElasticNet(alpha=a).fit(x,y)   
    score = model.score(x, y)
    pred_y = model.predict(x)
    mse = mean_squared_error(y, pred_y)   
    print("Alpha:{0:.4f}, R2:{1:.2f}, MSE:{2:.2f}, RMSE:{3:.2f}"
       .format(a, score, mse, np.sqrt(mse)))

elastic=ElasticNet(alpha=0.01).fit(xtrain, ytrain)
ypred = elastic.predict(xtest)
score = elastic.score(xtest, ytest)
mse = mean_squared_error(ytest, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))

x_ax = range(len(xtest))
plt.scatter(x_ax, ytest, s=5, color="blue", label="original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()


# --- ElasticNetCV ----
elastic_cv=ElasticNetCV(alphas=alphas, cv=5)
model = elastic_cv.fit(xtrain, ytrain)
print(model.alpha_)
print(model.intercept_)

ypred = model.predict(xtest)
score = model.score(xtest, ytest)
mse = mean_squared_error(ytest, ypred)
print("R2:{0:.3f}, MSE:{1:.2f}, RMSE:{2:.2f}"
      .format(score, mse, np.sqrt(mse)))

x_ax = range(len(xtest))
plt.scatter(x_ax, ytest, s=5, color="blue", label="original")
plt.plot(x_ax, ypred, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-533-ae1a1452c3ca> in <module>
#       6 import numpy as np
#       7
# ----> 8 xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.30)
#       9
#      10 alphas = [0.0001, 0.001, 0.01, 0.1, 0.3, 0.5, 0.7, 1]
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2125         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2126
# -> 2127     arrays = indexable(*arrays)
#    2128
#    2129     n_samples = _num_samples(arrays[0])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     290     """
#     291     result = [_make_indexable(X) for X in iterables]
# --> 292     check_consistent_length(*result)
#     293     return result
#     294
#
# ...

# %%
fig, ax = plt.subplots()
ax.scatter(y_test, pred)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Truths')
ax.set_ylabel('Predicted Values')
ax.set_title('COVID-19 Deaths - Elastic Net Regression')
plt.show()
ax.figure.savefig("elasticnetregression.jpg", transparent=True, bbox_inches='tight')

# %%
from sklearn.svm import SVR

svr_model = SVR()

svr_model.fit(X_train, y_train)

pred = svr_model.predict(X_train)

print(np.sqrt(mean_squared_error(y_train, pred, squared=False)))
print(r2_score(y_train, pred))
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 83.12821994683158
# -0.062139392498009594

# %%
svr = SVR()

cv = RepeatedKFold(n_splits = 5, n_repeats = 3, random_state=1)

scores = cross_val_score(svr, X, y, cv=cv)

#scores

print('MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
from sklearn.ensemble import BaggingRegressor

bag = BaggingRegressor()

bag.fit(X_train, y_train)

pred = bag.predict(X_train)

print(np.sqrt(mean_squared_error(y_train, pred, squared=False)))
print(r2_score(y_train, pred))
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# 37.28044228491202
# 0.9570352967209628

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from numpy import mean
from numpy import std

cv = RepeatedKFold(n_splits = 5, n_repeats = 3, random_state=1)

scores = cross_val_score(bag, X_scaled, y_scaled, cv=cv)

#scores

print('MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
param_dist = {"n_estimators": [10, 25, 50, 100]}

breg = BaggingRegressor()

rrandom = RandomizedSearchCV(estimator=breg, param_distributions=param_dist, cv=10, n_iter=100, random_state=42)
rrandom.fit(X, y)

print(rrandom.best_score_)
print(rrandom.best_estimator_)
print(rrandom.best_params_)
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:278: UserWarning: The total space of parameters 4 is smaller than n_iter=100. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
bag = BaggingRegressor(n_estimators=50)

cv = RepeatedKFold(n_splits = 5, n_repeats = 3, random_state=1)

scores = cross_val_score(bag, X, y, cv=cv)

#scores

print('MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

param_dist = {"n_estimators": [10, 25, 50, 100, 500, 1000],
             "max_depth": [1,5,10,25,50,100]}

rfr = RandomForestRegressor()

rrandom = RandomizedSearchCV(estimator=rfr, param_distributions=param_dist, cv=10, n_iter=100, random_state=42)
rrandom.fit(X, y)

print(rrandom.best_score_)
print(rrandom.best_estimator_)
print(rrandom.best_params_)
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:278: UserWarning: The total space of parameters 36 is smaller than n_iter=100. Running 36 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
rfr = RandomForestRegressor(max_depth=5, n_estimators=500)
cv = RepeatedKFold(n_splits = 5, n_repeats = 3, random_state=1)

scores = cross_val_score(rfr, X, y, cv=cv)

#scores

print('MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
from sklearn.kernel_ridge import KernelRidge

param_dist = {"alpha": [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]}

krr = KernelRidge()

rrandom = RandomizedSearchCV(estimator=krr, param_distributions=param_dist, cv=10, n_iter=100, random_state=42)
rrandom.fit(X, y)

print(rrandom.best_score_)
print(rrandom.best_estimator_.alpha)
print(rrandom.best_params_)
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:278: UserWarning: The total space of parameters 7 is smaller than n_iter=100. Running 7 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# 0.006975434446652651
# 100
# {'alpha': 100}

# %%
krr = KernelRidge(alpha=100)
cv = RepeatedKFold(n_splits = 5, n_repeats = 3, random_state=1)

scores = cross_val_score(krr, X, y, cv=cv)

#scores

print('MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# MAE: 0.339 (0.036)

# %%
from sklearn.ensemble import GradientBoostingRegressor

param_dist = {"n_estimators": [10, 25, 50, 100, 500, 1000]}

gbr = GradientBoostingRegressor()

rrandom = RandomizedSearchCV(estimator=gbr, param_distributions=param_dist, cv=10, n_iter=100, random_state=42)
rrandom.fit(X, y)

print(rrandom.best_score_)
print(rrandom.best_estimator_.alpha)
print(rrandom.best_params_)
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:278: UserWarning: The total space of parameters 6 is smaller than n_iter=100. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# -0.8509633040403116
# 0.9
# {'n_estimators': 100}

# %%
gbr = GradientBoostingRegressor(alpha=0.9, n_estimators=100)
cv = RepeatedKFold(n_splits = 5, n_repeats = 3, random_state=1)

scores = cross_val_score(gbr, X, y, cv=cv)

#scores

print('MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# MAE: 0.400 (0.162)

# %%
# !pip install xgboost

# %%
from xgboost import XGBRegressor

# %%
xgbr = XGBRegressor(objective='reg:squarederror')

cv = RepeatedKFold(n_splits = 5, n_repeats = 3, random_state=1)

scores = cross_val_score(xgbr, X, y, cv=cv)

#scores

print('MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\Users\12525\anaconda3\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\Users\12525\anaconda3\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# C:\Users\12525\anaconda3\lib\site-packages\xgboost\data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# ...

# %%
from sklearn.neighbors import KNeighborsRegressor

param_dist = {"n_neighbors": [2,3,4,5,6,7,8,9,10]}

knnr = KNeighborsRegressor()

rrandom = RandomizedSearchCV(estimator=knnr, param_distributions=param_dist, cv=10, n_iter=100, random_state=42)
rrandom.fit(X_scaled, y_scaled)

print(rrandom.best_score_)
print(rrandom.best_estimator_)
print(rrandom.best_params_)
# Out:
# C:\Users\12525\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:278: UserWarning: The total space of parameters 9 is smaller than n_iter=100. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# -1.2714197544791257
# KNeighborsRegressor(n_neighbors=10)
# {'n_neighbors': 10}

# %%
knnr = KNeighborsRegressor(n_neighbors=10)

cv = RepeatedKFold(n_splits = 5, n_repeats = 3, random_state=1)

scores = cross_val_score(knnr, X_scaled, y_scaled, cv=cv)

#scores

print('MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# MAE: 0.481 (0.062)
